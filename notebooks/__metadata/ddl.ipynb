# %% [markdown]
# #### DDL

# %% [markdown]
# #### Master Table

# %%
# %sql
CREATE TABLE IF NOT EXISTS master
(
    pipeline_name STRING,
    adf_id STRING,
    run_id STRING,
    run_date TIMESTAMP,
    run_status STRING,
    databricks_job_id STRING,
    databricks_job_status STRING,
    databricks_job_start_time TIMESTAMP,
    databricks_job_end_time TIMESTAMP,
    databricks_job_duration FLOAT,
    columns STRING,
    watermark_column STRING,
    last_successful_watermark TIMESTAMP,
    pipeline_admin STRING
)
USING DELTA
LOCATION 's3://data-and-analytics-assets/__metadata/master'
